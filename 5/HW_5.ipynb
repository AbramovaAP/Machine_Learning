# %% [markdown]
# # Урок 5: Оцениваем точность моделей с помощью разнообразных метрик
# Используя набор данных о домах, примените метрики для оценки качества модели регрессии. Затем, используя набор данных об ирисах, примените метрики для оценки качества модели классификации.
#
# Шаги для выполнения задания:
#
# 1. Загрузите набор данных о домах и набор данных об ирисах.
#
# 2. Разделите данные на обучающую и тестовую выборки.
#
# 3. Создайте модель регрессии и обучите ее на обучающей выборке.
#
# 4. Примените метрики для оценки качества модели регрессии на тестовой выборке.
#
# 5. Создайте модель классификации и обучите ее на обучающей выборке.
#
# 6. Примените метрики для оценки качества модели классификации на тестовой выборке.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
import numpy as np

# %% [markdown]
# ## 1. Загрузите набор данных о домах и набор данных об ирисах.

# %%
# Загрузка данных о домах
house_data = pd.read_csv("boston.csv")

# %%
house_data
# Out:
#         CRIM    ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NX       506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
house_data.duplicated().sum()
# Out:
# 0

# %%
house_data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NX         0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
house_data.describe().T.style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_6a210_row0_col0, #T_6a210_row0_col3, #T_6a210_row0_col4, #T_6a210_row0_col5, #T_6a210_row1_col0, #T_6a210_row1_col3, #T_6a210_row1_col4, #T_6a210_row1_col5, #T_6a210_row2_col0, #T_6a210_row2_col3, #T_6a210_row3_col0, #T_6a210_row3_col1, #T_6a210_row3_col2, #T_6a210_row3_col3, #T_6a210_row3_col4, #T_6a210_row3_col5, #T_6a210_row3_col6, #T_6a210_row3_col7, #T_6a210_row4_col0, #T_6a210_row4_col1, #T_6a210_row4_col2, #T_6a210_row4_col3, #T_6a210_row4_col4, #T_6a210_row4_col5, #T_6a210_row4_col6, #T_6a210_row4_col7, #T_6a210_row5_col0, #T_6a210_row5_col2, #T_6a210_row6_col0, #T_6a210_row7_col0, #T_6a210_row8_col0, #T_6a210_row9_col0, #T_6a210_row10_col0, #T_6a210_row11_col0, #T_6a210_row11_col3, #T_6a210_row12_col0, #T_6a210_row13_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_6a210_row0_col1, #T_6a210_row5_col6, #T_6a210_row5_col7, #T_6a210_row7_col1, #T_6a210_row7_col5, #T_6a210_row8_col4, #T_6a210_row12_col3 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_6a210_row0_col2, #T_6a210_row10_col5 {
#   background-color: #fff8bb;
#   color: #000000;
# }
# #T_6a210_row0_col6, #T_6a210_row7_col3, #T_6a210_row7_col4, #T_6a210_row7_col6, #T_6a210_row8_col3 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_6a210_row0_col7 {
#   background-color: #ffeda1;
#   color: #000000;
# }
# #T_6a210_row1_col1, #T_6a210_row10_col6, #T_6a210_row10_col7, #T_6a210_row12_col1, #T_6a210_row12_col5 {
#   background-color: #fffbc2;
#   color: #000000;
# }
# #T_6a210_row1_col2, #T_6a210_row1_col7, #T_6a210_row6_col7 {
#   background-color: #ffeb9c;
#   color: #000000;
# }
# #T_6a210_row1_col6, #T_6a210_row5_col3, #T_6a210_row5_col4, #T_6a210_row5_col5, #T_6a210_row7_col7, #T_6a210_row12_col4 {
#   background-color: #fffdc6;
#   color: #000000;
# }
# #T_6a210_row2_col1, #T_6a210_row2_col5, #T_6a210_row2_col6, #T_6a210_row12_col6, #T_6a210_row13_col3 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_6a210_row2_col2, #T_6a210_row12_col2 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_6a210_row2_col4, #T_6a210_row5_col1, #T_6a210_row6_col3, #T_6a210_row7_col2, #T_6a210_row8_col5, #T_6a210_row10_col2 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_6a210_row2_col7, #T_6a210_row8_col6, #T_6a210_row13_col6 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_6a210_row6_col1, #T_6a210_row6_col2 {
#   background-color: #ffe793;
#   color: #000000;
# }
# #T_6a210_row6_col4 {
#   background-color: #ffeea3;
#   color: #000000;
# }
# #T_6a210_row6_col5 {
#   background-color: #fee288;
#   color: #000000;
# }
# #T_6a210_row6_col6 {
#   background-color: #ffea9b;
#   color: #000000;
# }
# #T_6a210_row8_col1 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_6a210_row8_col2, #T_6a210_row12_col7, #T_6a210_row13_col2, #T_6a210_row13_col5 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_6a210_row8_col7 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_6a210_row9_col1, #T_6a210_row9_col2, #T_6a210_row9_col3, #T_6a210_row9_col6, #T_6a210_row9_col7, #T_6a210_row11_col4, #T_6a210_row11_col5 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_6a210_row9_col4 {
#   background-color: #e41c1d;
#   color: #f1f1f1;
# }
# #T_6a210_row9_col5 {
#   background-color: #c70723;
#   color: #f1f1f1;
# }
# #T_6a210_row10_col1, #T_6a210_row10_col4, #T_6a210_row13_col4 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_6a210_row10_col3, #T_6a210_row13_col7 {
#   background-color: #fff5b5;
#   color: #000000;
# }
# #T_6a210_row11_col1 {
#   background-color: #bd0026;
#   color: #f1f1f1;
# }
# #T_6a210_row11_col2 {
#   background-color: #fd7836;
#   color: #f1f1f1;
# }
# #T_6a210_row11_col6 {
#   background-color: #fc5d2e;
#   color: #f1f1f1;
# }
# #T_6a210_row11_col7 {
#   background-color: #fd7034;
#   color: #f1f1f1;
# }
# #T_6a210_row13_col1 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# </style>
# <table id="T_6a210">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a210_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_6a210_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_6a210_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_6a210_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_6a210_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_6a210_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_6a210_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_6a210_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a210_level0_row0" class="row_heading level0 row0" >CRIM</th>
#       <td id="T_6a210_row0_col0" class="data row0 col0" >506.000000</td>
#       <td id="T_6a210_row0_col1" class="data row0 col1" >3.613524</td>
#       <td id="T_6a210_row0_col2" class="data row0 col2" >8.601545</td>
#       <td id="T_6a210_row0_col3" class="data row0 col3" >0.006320</td>
#       <td id="T_6a210_row0_col4" class="data row0 col4" >0.082045</td>
#       <td id="T_6a210_row0_col5" class="data row0 col5" >0.256510</td>
#       <td id="T_6a210_row0_col6" class="data row0 col6" >3.677083</td>
#       <td id="T_6a210_row0_col7" class="data row0 col7" >88.976200</td>
#     </tr>
#     <tr>
#       <th id="T_6a210_level0_row1" class="row_heading level0 row1" >ZN</th>
#       <td id="T_6a210_row1_col0" class="data row1 col0" >506.000000</td>
#       <td id="T_6a210_row1_col1" class="data row1 col1" >11.363636</td>
#       <td id="T_6a210_row1_col2" class="data row1 col2" >23.322453</td>
#       <td id="T_6a210_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_6a210_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_6a210_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_6a210_row1_col6" class="data row1 col6" >12.500000</td>
#       <td id="T_6a210_row1_col7" class="data row1 col7" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6a210_level0_row2" class="row_heading level0 row2" >INDUS</th>
#       <td id="T_6a210_row2_col0" class="data row2 col0" >506.000000</td>
#       <td id="T_6a210_row2_col1" class="data row2 col1" >11.136779</td>
#       <td id="T_6a210_row2_col2" class="data row2 col2" >6.860353</td>
#       <td id="T_6a210_row2_col3" class="data row2 col3" >0.460000</td>
#       <td id="T_6a210_row2_col4" class="data row2 col4" >5.190000</td>
#       <td id="T_6a210_row2_col5" class="data row2 col5" >9.690000</td>
#       <td id="T_6a210_row2_col6" class="data row2 col6" >18.100000</td>
#       <td id="T_6a210_row2_col7" class="data row2 col7" >27.740000</td>
#     </tr>
#     <tr>
#       <th id="T_6a210_level0_row3" class="row_heading level0 row3" >CHAS</th>
#       <td id="T_6a210_row3_col0" class="data row3 col0" >506.000000</td>
#       <td id="T_6a210_row3_col1" class="data row3 col1" >0.069170</td>
#       <td id="T_6a210_row3_col2" class="data row3 col2" >0.253994</td>
#       <td id="T_6a210_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_6a210_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_6a210_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_6a210_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_6a210_row3_col7" class="data row3 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6a210_level0_row4" class="row_heading level0 row4" >NX</th>
#       <td id="T_6a210_row4_col0" class="data row4 col0" >506.000000</td>
#       <td id="T_6a210_row4_col1" class="data row4 col1" >0.554695</td>
#       <td id="T_6a210_row4_col2" class="data row4 col2" >0.115878</td>
#       <td id="T_6a210_row4_col3" class="data row4 col3" >0.385000</td>
#       <td id="T_6a210_row4_col4" class="data row4 col4" >0.449000</td>
#       <td id="T_6a210_row4_col5" class="data row4 col5" >0.538000</td>
#       <td id="T_6a210_row4_col6" class="data row4 col6" >0.624000</td>
#       <td id="T_6a210_row4_col7" class="data row4 col7" >0.871000</td>
#     </tr>
#     <tr>
#       <th id="T_6a210_level0_row5" class="row_heading level0 row5" >RM</th>
#       <td id="T_6a210_row5_col0" class="data row5 col0" >506.000000</td>
#       <td id

# %%
# Загрузка данных об ирисах
iris_data = pd.read_csv("Iris.csv")
iris_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris_data.duplicated().sum()
# Out:
# 0

# %%
iris_data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris_data.describe().T.style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_c40bb_row0_col0, #T_c40bb_row1_col0, #T_c40bb_row2_col0, #T_c40bb_row2_col2, #T_c40bb_row3_col0, #T_c40bb_row4_col0, #T_c40bb_row4_col1, #T_c40bb_row4_col3, #T_c40bb_row4_col4, #T_c40bb_row4_col5, #T_c40bb_row4_col6, #T_c40bb_row4_col7 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_c40bb_row0_col1, #T_c40bb_row0_col2, #T_c40bb_row0_col4, #T_c40bb_row0_col5, #T_c40bb_row0_col6, #T_c40bb_row0_col7, #T_c40bb_row1_col3 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_c40bb_row0_col3, #T_c40bb_row3_col3 {
#   background-color: #fedf83;
#   color: #000000;
# }
# #T_c40bb_row1_col1, #T_c40bb_row2_col4 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_c40bb_row1_col2 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_c40bb_row1_col4 {
#   background-color: #ffeda0;
#   color: #000000;
# }
# #T_c40bb_row1_col5 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_c40bb_row1_col6, #T_c40bb_row3_col5 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_c40bb_row1_col7 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_c40bb_row2_col1 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_c40bb_row2_col3 {
#   background-color: #fd9c42;
#   color: #000000;
# }
# #T_c40bb_row2_col5 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_c40bb_row2_col6, #T_c40bb_row2_col7 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_c40bb_row3_col1, #T_c40bb_row3_col4 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_c40bb_row3_col2, #T_c40bb_row3_col6, #T_c40bb_row3_col7 {
#   background-color: #fffbc2;
#   color: #000000;
# }
# #T_c40bb_row4_col2 {
#   background-color: #fffecb;
#   color: #000000;
# }
# </style>
# <table id="T_c40bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c40bb_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_c40bb_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_c40bb_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_c40bb_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_c40bb_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_c40bb_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_c40bb_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_c40bb_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c40bb_level0_row0" class="row_heading level0 row0" >Id</th>
#       <td id="T_c40bb_row0_col0" class="data row0 col0" >150.000000</td>
#       <td id="T_c40bb_row0_col1" class="data row0 col1" >75.500000</td>
#       <td id="T_c40bb_row0_col2" class="data row0 col2" >43.445368</td>
#       <td id="T_c40bb_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_c40bb_row0_col4" class="data row0 col4" >38.250000</td>
#       <td id="T_c40bb_row0_col5" class="data row0 col5" >75.500000</td>
#       <td id="T_c40bb_row0_col6" class="data row0 col6" >112.750000</td>
#       <td id="T_c40bb_row0_col7" class="data row0 col7" >150.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c40bb_level0_row1" class="row_heading level0 row1" >SepalLengthCm</th>
#       <td id="T_c40bb_row1_col0" class="data row1 col0" >150.000000</td>
#       <td id="T_c40bb_row1_col1" class="data row1 col1" >5.843333</td>
#       <td id="T_c40bb_row1_col2" class="data row1 col2" >0.828066</td>
#       <td id="T_c40bb_row1_col3" class="data row1 col3" >4.300000</td>
#       <td id="T_c40bb_row1_col4" class="data row1 col4" >5.100000</td>
#       <td id="T_c40bb_row1_col5" class="data row1 col5" >5.800000</td>
#       <td id="T_c40bb_row1_col6" class="data row1 col6" >6.400000</td>
#       <td id="T_c40bb_row1_col7" class="data row1 col7" >7.900000</td>
#     </tr>
#     <tr>
#       <th id="T_c40bb_level0_row2" class="row_heading level0 row2" >SepalWidthCm</th>
#       <td id="T_c40bb_row2_col0" class="data row2 col0" >150.000000</td>
#       <td id="T_c40bb_row2_col1" class="data row2 col1" >3.054000</td>
#       <td id="T_c40bb_row2_col2" class="data row2 col2" >0.433594</td>
#       <td id="T_c40bb_row2_col3" class="data row2 col3" >2.000000</td>
#       <td id="T_c40bb_row2_col4" class="data row2 col4" >2.800000</td>
#       <td id="T_c40bb_row2_col5" class="data row2 col5" >3.000000</td>
#       <td id="T_c40bb_row2_col6" class="data row2 col6" >3.300000</td>
#       <td id="T_c40bb_row2_col7" class="data row2 col7" >4.400000</td>
#     </tr>
#     <tr>
#       <th id="T_c40bb_level0_row3" class="row_heading level0 row3" >PetalLengthCm</th>
#       <td id="T_c40bb_row3_col0" class="data row3 col0" >150.000000</td>
#       <td id="T_c40bb_row3_col1" class="data row3 col1" >3.758667</td>
#       <td id="T_c40bb_row3_col2" class="data row3 col2" >1.764420</td>
#       <td id="T_c40bb_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_c40bb_row3_col4" class="data row3 col4" >1.600000</td>
#       <td id="T_c40bb_row3_col5" class="data row3 col5" >4.350000</td>
#       <td id="T_c40bb_row3_col6" class="data row3 col6" >5.100000</td>
#       <td id="T_c40bb_row3_col7" class="data row3 col7" >6.900000</td>
#     </tr>
#     <tr>
#       <th id="T_c40bb_level0_row4" class="row_heading level0 row4" >PetalWidthCm</th>
#       <td id="T_c40bb_row4_col0" class="data row4 col0" >150.000000</td>
#       <td id="T_c40bb_row4_col1" class="data row4 col1" >1.198667</td>
#       <td id="T_c40bb_row4_col2" class="data row4 col2" >0.763161</td>
#       <td id="T_c40bb_row4_col3" class="data row4 col3" >0.100000</td>
#       <td id="T_c40bb_row4_col4" class="data row4 col4" >0.300000</td>
#       <td id="T_c40bb_row4_col5" class="data row4 col5" >1.300000</td>
#       <td id="T_c40bb_row4_col6" class="data row4 col6" >1.800000</td>
#       <td id="T_c40bb_row4_col7" class="data row4 col7" >2.500000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2. Разделите данные на обучающую и тестовую выборки.

# %%
# Для данных о домах
X_house = house_data.drop("MEDV", axis=1)
y_house = house_data["MEDV"]
X_house_train, X_house_test, y_house_train, y_house_test = train_test_split(
    X_house, y_house, test_size=0.3, random_state=42
)

# %%
# Для данных об ирисах
X_iris = iris_data.drop("Species", axis=1)
y_iris = iris_data["Species"]
X_iris_train, X_iris_test, y_iris_train, y_iris_test = train_test_split(
    X_iris, y_iris, test_size=0.3, random_state=42)

# %% [markdown]
# ## 3. Создайте модель регрессии и обучите ее на обучающей выборке.

# %%
# Создание модели линейной регрессии
model_regression = LinearRegression()

# %%
# Обучение модели на обучающей выборке
model_regression.fit(X_house_train, y_house_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## 4. Примените метрики для оценки качества модели регрессии на тестовой выборке.

# %%
# Предсказание на тестовой выборке
y_house_pred = model_regression.predict(X_house_test)

# %%
# Вычисление метрик качества
mae = mean_absolute_error(y_house_test, y_house_pred)
11
mse = mean_squared_error(y_house_test, y_house_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_house_test, y_house_pred)
# Вывод результатов
print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R^2: {r2:.2f}")
# Out:
# MAE: 3.16
# MSE: 21.52
# RMSE: 4.64
# R^2: 0.71

# %% [markdown]
# Эти данные позволяют сделать следующие выводы:
#
# Rjhtym cреднеквадратической ошибки (RMSE): 4.67
#
#  RMSE  - это мера того, насколько хорошо модель предсказывает фактические значения.
#  Чем меньше RMSE, тем лучше модель.
#
#
# Коэффициент детерминации (R^2): 0.71
#
#  R^2  - это мера того, насколько хорошо модель объясняет изменения в данных.
#  R^2 принимает значения от 0 до 1. Чем ближе R^2 к 1, тем лучше модель объясняет данные.
#  В данном случае R^2 равен 0.71, что означает, что модель объясняет 71% изменений в данных.
#  Это хороший показатель, так как  R^2 больше 0.5, что свидетельствует о том, что модель достаточно хорошо объясняет данные.
#
# Вывод:
#
#  Модель достаточно неплохо предсказывает фактические значения, но есть пространство для улучшения.
#  R^2 показывает, что модель хорошо объясняет изменения в данных.
#  Для более точной оценки качества модели необходимо знать конкретную задачу и тип данных.
#
# Рекомендуемые действия:
#
#  Сравнить эту модель с другими моделями, чтобы оценить ее эффективность.
#  Попробовать улучшить модель, например, добавив новые переменные или изменив алгоритм.
#  Проанализировать остатки модели, чтобы проверить,  есть ли какие-то систематические ошибки.

# %% [markdown]
# ## 5. Создайте модель классификации и обучите ее на обучающей выборке.

# %%
# Создание модели k-ближайших соседей
model_classification = KNeighborsClassifier(n_neighbors=2)

# %%
# Обучение модели k-neibours на обучающей выборке
model_classification.fit(X_iris_train, y_iris_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %% [markdown]
# ## 6. Примените метрики для оценки качества модели классификации на тестовой выборке.

# %%
# Предсказание на тестовой выборке
y_iris_pred1 = model_classification.predict(X_iris_test)

# %%
# Вычисление метрик качества
accuracy = accuracy_score(y_iris_test, y_iris_pred1)
precision = precision_score(y_iris_test, y_iris_pred1, average="macro")
recall = recall_score(y_iris_test, y_iris_pred1, average="macro")
f1 = f1_score(y_iris_test, y_iris_pred1, average="macro")
confusion_mat = confusion_matrix(y_iris_test, y_iris_pred1)

# %%
print(f"Точность: {accuracy:.2f}")
print(f"Точность (Precision): {precision:.2f}")
print(f"Полнота (Recall): {recall:.2f}")
print(f"F1-мера: {f1:.2f}")
print("Матрица ошибок:\n", confusion_mat)
# Out:
# Точность: 1.00
# Точность (Precision): 1.00
# Полнота (Recall): 1.00
# F1-мера: 1.00
# Матрица ошибок:
#  [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]

# %%
print(classification_report(y_iris_test, y_iris_pred1))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45

# %%
import seaborn as sns

# %%
# Визуализация матрицы ошибок
sns.heatmap(confusion_mat, annot=True, fmt="d", cmap = "Blues")
plt.xlabel("Прогноз")
plt.ylabel("Фактическое значение")
plt.title("Матрица ошибок")
plt.show();

# %% [markdown]
# Эти данные показывают идеальную производительность модели.
#
# Объяснение:
#
#  Точность (Precision)  = 1.00 означает, что все предсказанные положительные случаи были действительно положительными. Другими словами, модель не сделала ни одной ложноположительной ошибки.
#  Полнота (Recall) = 1.00 означает, что модель нашла все положительные случаи. Другими словами, модель не пропустила ни одного положительного случая.
#  F1-мера = 1.00  является гармоническим средним точности и полноты. Поскольку оба показателя равны 1.00, F1-мера также равна 1.00, что подтверждает идеальную производительность модели.
#
# В целом, данные указывают на то, что модель прекрасно справляется с задачей классификации и не делает ошибок.
#
# Однако, важно учитывать контекст:
#
#  Размер выборки: Идеальные показатели могут быть достигнуты на очень маленькой выборке.
#  Сложность задачи: Простые задачи классификации могут быть легко решены даже простыми моделями.
#  Сбалансированность данных: Идеальные показатели могут быть достигнуты, если данные сильно сбалансированы (т.е. количество положительных и отрицательных примеров одинаково).
#
# Важно проверить эти показатели на разных выборках данных (например, на тестовой выборке), чтобы убедиться, что модель действительно работает хорошо и не переобучается.
#
# **Интерпретация confusion_matrix - в тестовой выборке все 19 объектов класса 0 были правильно отнесены к классу 0, все 13 объектов класса 1 были правильно отнесены к классу 1, все 13 объектов класса 2 были правильно отнесены к классу 2, неправильно классифицированных объектов не было.**
